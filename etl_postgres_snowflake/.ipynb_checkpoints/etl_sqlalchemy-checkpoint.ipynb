# %%
# Database integration from PostgreSQL into Pandas

import pandas as pd
from sqlalchemy import create_engine

# establish a connection engine to your PostgreSQL database (source db)
# connection string format = (dialect+driver://username:password@host:port/database)

source_engine = create_engine("postgresql+psycopg2://postgres:QztLWcoQoMcFPKoKgCyuDwUPjOHUYdtO@trolley.proxy.rlwy.net:50067/railway")

query = """ SELECT *
        FROM customers
        """

df_read = pd.read_sql(query, source_engine)
df_read.shape
# Out:
# (124, 14)

# %%
df_read
# Out:
#       id first_name   last_name                       email  \
# 0      1       Test        User           testuser@test.com
# 1      2      Ahmed     Oladapo           biyiguy@gmail.com
# 2     53      Megan  Stephenson         donna55@example.com
# 3     54     Lauren     Flowers        judith52@example.net
# 4     55    Charles     Ramirez  proctorcharles@example.org
# ..   ...        ...         ...                         ...
# 119  170        Amy      Bailey     lewisjustin@example.com
# 120  171    Kathryn       Lopez   nunezmargaret@example.org
# 121  172       Cole      Miller         kelly73@example.net
# 122  173   Chidinma        Okeh    chidinmaokeh75@gmail.com
# 123  174       Lola       Bakre  Lardivahapparels@gmail.com
#
#                     phone                          address    city   state  \
# 0                    None                             None    None    None
# 1          +2349091390809                    230 borno way   lagos    Abia
# 2        001-292-983-4859        10808 Mary Mall Suite 271  Ibadan    None
# 3       (396)349-3118x207                9945 Pamela Field    Kano    None
# 4    001-876-237-8316x690               951 Adam Mountains   Lagos    None
# ..                    ...                              ...     ...     ...
# 119      001-894-402-8752  167 Garrett Stravenue Suite 152  Ibadan    None
# 120          341.522.6218                09137 Robert Pass   Enugu    None
# 121          576-639-6093                398 Decker Corner   Abuja    None
# 122        +2348169101205                    Alapere Lagos   Lagos   Lagos
# 123         9869986848769                 23 seidu okeleji   Lagos  Logos
#
#      country postal_code                                           password  \
# 0    Nigeria        None  $2b$12$8LYwj2E2rHoTauQlCWOKh.l.riliw5AWEDhZ6et...
# 1    Nigeria      234101  $2b$12$fi1k5SMmbZWQ5hwIKi/cs.u4wjr8cKtiHNxAzzE...
# 2    Nigeria        None  $2b$12$tII5OYX1LCB7W/k7a6o3teAkMMGuGC59QHShF3....
# 3    Nigeria        None  $2b$12$UnXHrfcWhkPiTGn9yAzJ5eb19no19qluCIBRXb/...
# 4    Nigeria        None  $2b$12$srDCNrvh0yiFZskuAoKVz.3kLptk5M5YQzTRnqL...
# ..       ...         ...                                                ...
# 119  Nigeria        None  $2b$12$ajr9KWpgXw.FuZpN8C1doOcgcWDstJNPhNRLykf...
# 120  Nigeria        None  $2b$12$8sWZO7BUWIuDVF2seIYkT..H0tRF.wa14aVzogy...
# 121  Nigeria        None  $2b$12$HKX3nfHTzPgWpjeeear1g.QQNM93qSQnFwvwiMt...
# 122  Nigeria        None  $2b$12$DUeUjJ/LMQbRsRQgSR.EPOONYBe7jUeL/Q487cx...
# 123  Nigeria       10001  $2b$12$4LX6meMWBLd2eI0extpfAOSKvkkAUw6YSVrSLu0...
#
#      is_active                       created_at  \
# 0         True 2026-03-11 02:39:43.500028+00:00
# 1         True 2026-03-11 02:40:19.433485+00:00
# 2         True 2026-03-11 02:48:42.266872+00:00
# 3         True 2026-03-11 02:48:42.266872+00:00
# 4         True 2026-03-11 02:48:42.266872+00:00
# ..         ...                              ...
# 119       True 2026-03-11 02:56:30.034334+00:00
# 120       True 2026-03-11 02:56:30.034334+00:00
# 121       True 2026-03-11 02:56:30.034334+00:00
# 122       True 2026-03-17 09:30:43.993873+00:00
# 123       True 2026-03-18 21:12:21.072851+00:00
#
#                           updated_at
# 0   2026-03-11 02:39:43.500028+00:00
# 1   2026-03-11 02:40:19.433485+00:00
# 2   2026-03-11 02:48:42.266872+00:00
# 3   2026-03-11 02:48:42.266872+00:00
# 4   2026-03-11 02:48:42.266872+00:00
# ..                               ...
# 119 2026-03-11 02:56:30.034334+00:00
# 120 2026-03-11 02:56:30.034334+00:00
# 121 2026-03-11 02:56:30.034334+00:00
# 122 2026-03-17 09:30:43.993873+00:00
# 123 2026-03-18 21:12:21.072851+00:00
#
# [124 rows x 14 columns]
